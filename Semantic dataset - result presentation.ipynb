# %% [markdown]
# ## Imports

# %%
#General
import pandas as pd
import numpy as np
#Visualization
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib

# %% [markdown]
# ## Result analysis

# %%
models = ["DecisionTreeClassifier","GaussianNB","KNeighborsClassifier","LogisticRegression","REPD"]
datasets = [
    "ant",
    "camel",
    "log4j",
    "poi"
]
dataset_versions = {
    "ant":["1.5","1.6"],
    "camel":["1.2","1.4"],
    "log4j":["1.1","1.2"],
    "poi":["2.0","2.5"]
}
feature_types = ["dbn","da","ca"]
per_feature_type_count = 30
colnames = ['Unnamed: 0','Model', 'Accuracy', 'Precision', 'Recall', 'F1 score', "Dataset", "Version", "Feature_type", "i"]

# %%
font = {'size': 80}
matplotlib.rc('font', **font)

for dataset in datasets:
    for version in dataset_versions[dataset]:
        main_df = None
        #
        for feature_type in feature_types:
            for i in range(per_feature_type_count):
                results_df = pd.read_csv("results/"+dataset+'_'+version+'_'+feature_type+'_'+str(i),names=colnames, header=None)
                results_df = results_df.drop(columns=["Unnamed: 0"])
                #
                if main_df is None:
                    main_df = results_df
                else: 
                    main_df = pd.concat([main_df,results_df])
       
        #Print performance results     
        print(dataset,version)
        res = main_df.groupby(by=["Feature_type","Model"]).mean()["F1 score"]
        print()
        print(res)#.to_latex()
        print()
        
        """
        #Plot performance results
        for measure_name in ["F1 score","Recall","Precision"]:
            df = main_df.drop(columns=['Accuracy'])
            new_dfs = []

            for n, feature_type in enumerate(list(set(df.Feature_type.values))):
                new_df = []
                for model in list(set(df.Model.values)):
                    f1_scores = []
                    temp = df.loc[(df['Feature_type'] == feature_type) & (df['Model'] == model)][measure_name].values
                    for value in temp:
                        d = {
                            'Feature_typeModel' : '{: <26}'.format(", ".join([feature_type, model])), measure_name : value
                        }
                        new_df.append(d)

                new_df = pd.DataFrame(new_df)
                new_dfs.append(new_df)

            fig, axs = plt.subplots(3, 1, figsize=(64,64), sharex=True, sharey="row", gridspec_kw={'hspace': 0.1})

            for n, new_df in enumerate(new_dfs):
                ax=axs[n]
                sns.violinplot(measure_name,'Feature_typeModel', data=new_df, ax = ax)
                #
                yax = ax.get_yaxis()
                yax.grid(True)
                yax.set_ticks_position('right')
                pad = max([len(i) for i in new_df['Feature_typeModel'].values])
                yax.set_tick_params(pad=pad)
                y_label = yax.get_label()
                y_label.set_visible(False)
                #
                xax = ax.get_xaxis()
                xax.grid(True)
                x_label = xax.get_label()
                x_label.set_visible(False)
                #
                ax.set_title("")
            fig.suptitle(measure_name)
            st = fig.suptitle(measure_name, fontsize="x-large")
            st.set_y(0.95)
            fig.subplots_adjust(top=0.93)
            fig.tight_layout()
            plt.tight_layout()
            plt.savefig(dataset+"_"+version+"_"+measure_name+"_results.pdf",format='pdf',bbox_inches='tight')
            plt.show()
        """
# Out:
# ant 1.5
#
# Feature_type  Model
# ca            DecisionTreeClassifier    0.189696
#               GaussianNB                0.397834
#               HSME                      0.205727
#               KNeighborsClassifier      0.172217
#               LogisticRegression        0.000000
#               REPD                      0.346162
# da            DecisionTreeClassifier    0.193566
#               GaussianNB                0.348395
#               HSME                      0.230333
#               KNeighborsClassifier      0.257090
#               LogisticRegression        0.043307
#               REPD                      0.267059
# dbn           DecisionTreeClassifier    0.129656
#               GaussianNB                0.116983
#               HSME                      0.102012
#               KNeighborsClassifier      0.030831
#               LogisticRegression        0.076182
#               REPD                      0.197420
# Name: F1 score, dtype: float64
#
# ant 1.6
#
# Feature_type  Model
# ca            DecisionTreeClassifier    0.508716
#               GaussianNB                0.582417
#               HSME                      0.561219
#               KNeighborsClassifier      0.557047
#               LogisticRegression        0.035536
#               REPD                      0.598015
# da            DecisionTreeClassifier    0.496865
#               GaussianNB                0.639628
#               HSME                      0.558758
#               KNeighborsClassifier      0.561934
#               LogisticRegression        0.622797
#               REPD                      0.502594
# dbn           DecisionTreeClassifier    0.280716
#               GaussianNB                0.251207
#               HSME                      0.222997
#               KNeighborsClassifier      0.165928
#               LogisticRegression        0.227592
#               REPD                      0.416185
# Name: F1 score, dtype: float64
#
# camel 1.2
#
# Feature_type  Model
# ca            DecisionTreeClassifier    0.406636
#               GaussianNB                0.249717
#               HSME                      0.408568
#               KNeighborsClassifier      0.353825
#               LogisticRegression        0.009458
#               REPD                      0.367067
# da            DecisionTreeClassifier    0.402963
#               GaussianNB                0.261532
#               HSME                      0.407895
#               KNeighborsClassifier      0.365328
#               LogisticRegression        0.205698
#               REPD                      0.408060
# dbn           DecisionTreeClassifier    0.372293
#               GaussianNB                0.287516
#               HSME                      0.310125
#               KNeighborsClassifier      0.321183
#               LogisticRegression        0.316531
#               REPD                      0.522548
# Name: F1 score, dtype: float64
#
# camel 1.4
#
# Feature_type  Model
# ca            DecisionTreeClassifier    0.243573
#               GaussianNB                0.302870
#               HSME                      0.250649
#               KNeighborsClassifier      0.156291
#               LogisticRegression        0.000329
#               REPD                      0.308983
# da            DecisionTreeClassifier    0.247190
#               GaussianNB                0.338585
#               HSME                      0.264237
#               KNeighborsClassifier      0.222280
#               LogisticRegression        0.042981
#               REPD                      0.315469
# dbn           DecisionTreeClassifier    0.194492
#               GaussianNB                0.094989
#               HSME                      0.123143
#               KNeighborsClassifier      0.099778
#               LogisticRegression        0.100485
#               REPD                      0.286329
# Name: F1 score, dtype: float64
#
# log4j 1.1
#
# Feature_type  Model
# ca            DecisionTreeClassifier    0.560209
#               GaussianNB                0.620376
#               HSME                      0.586878
#               KNeighborsClassifier      0.592275
#               LogisticRegression        0.000000
#               REPD                      0.616309
# da            DecisionTreeClassifier    0.569430
#               GaussianNB                0.647497
#               HSME                      0.595270
#               KNeighborsClassifier      0.583312
#               LogisticRegression        0.624390
#               REPD                      0.499725
# dbn           DecisionTreeClassifier    0.373357
#               GaussianNB                0.283257
#               HSME                      0.293201
#               KNeighborsClassifier      0.296478
#               LogisticRegression        0.315052
#               REPD                      0.512572
# Name: F1 score, dtype: float64
#
# log4j 1.2
#
# Feature_type  Model
# ca            DecisionTreeClassifier    0.954714
#               GaussianNB                0.764254
#               HSME                      0.965047
#               KNeighborsClassifier      0.975682
#               LogisticRegression        0.979337
#               REPD                      0.801142
# da            DecisionTreeClassifier    0.954842
#               GaussianNB                0.686794
#               HSME                      0.956490
#               KNeighborsClassifier      0.973838
#               LogisticRegression        0.978951
#               REPD                      0.815192
# dbn           DecisionTreeClassifier    0.945529
#               GaussianNB                0.960846
#               HSME                      0.971853
#               KNeighborsClassifier      0.975960
#               LogisticRegression        0.977559
#               REPD                      0.977559
# Name: F1 score, dtype: float64
#
# poi 2.0
#
# Feature_type  Model
# ca            DecisionTreeClassifier    0.185313
#               GaussianNB                0.238014
#               HSME                      0.162414
#               KNeighborsClassifier      0.088332
#               LogisticRegression        0.000000
#               REPD                      0.235891
# da            DecisionTreeClassifier    0.164166
#               GaussianNB                0.219852
#               HSME                      0.165109
#               KNeighborsClassifier      0.082576
#               LogisticRegression        0.103604
#               REPD                      0.216939
# dbn           DecisionTreeClassifier    0.144996
#               GaussianNB                0.129094
#               HSME                      0.102902
#               KNeighborsClassifier      0.043416
#               LogisticRegression        0.086470
#               REPD                      0.212441
# Name: F1 score, dtype: float64
#
# poi 2.5
#
# Feature_type  Model
# ca            DecisionTreeClassifier    0.744520
#               GaussianNB                0.535112
#               HSME                      0.754769
#               KNeighborsClassifier      0.785134
#               LogisticRegression        0.792170
#               REPD                      0.573311
# da            DecisionTreeClassifier    0.736676
#               GaussianNB                0.576708
#               HSME                      0.737964
#               KNeighborsClassifier      0.773874
#               LogisticRegression        0.817816
#               REPD                      0.686932
# dbn           DecisionTreeClassifier    0.639665
#               GaussianNB                0.667530
#               HSME                      0.651827
#               KNeighborsClassifier      0.673524
#               LogisticRegression        0.668636
#               REPD                      0.785054
# Name: F1 score, dtype: float64

# %%
from scipy.stats import sem, t
from scipy import mean

# %%
confidence = 0.95
for dataset in datasets:
    for version in dataset_versions[dataset]:
        main_df = None
        #
        for feature_type in feature_types:
            for i in range(per_feature_type_count):
                results_df = pd.read_csv("results/"+dataset+'_'+version+'_'+feature_type+'_'+str(i),names=colnames, header=None)
                results_df = results_df.drop(columns=["Unnamed: 0"])
                #
                if main_df is None:
                    main_df = results_df
                else: 
                    main_df = pd.concat([main_df,results_df])
                    
        print(dataset,version)
        for feature_type in feature_types:
            intervals = []
            for model in models:
                f1_values = main_df[(main_df["Feature_type"]==feature_type) & (main_df["Model"]==model)]["F1 score"].values
                #
                n = len(f1_values)
                m = mean(f1_values)
                std_err = sem(f1_values)
                h = std_err * t.ppf((1 + confidence) / 2, n - 1)
                #
                start = m-h
                end = m+h
                intervals.append((model,start,end))
                #
                print("\t",feature_type, model, n, round(m,4),"+/-",round(h,4))
            count = 0
            for i in range(len(intervals)):
                for j in range(i+1,len(intervals)):
                    m1,s1,e1 = intervals[i]
                    m2,s2,e2 = intervals[j]
                    if s1 <= e2 and s2 <= e1:
                        if m1=="REPD" or m2=="REPD":
                            count = count + 1
                            print(m1,m2)
            if count > 0:
                print("Overlap count:", count)
            print()
        print()
        print()
# Out:
# ant 1.5
# 	 dbn DecisionTreeClassifier 900 0.1297 +/- 0.0077
# 	 dbn GaussianNB 900 0.117 +/- 0.0082
# 	 dbn KNeighborsClassifier 900 0.0308 +/- 0.0057
# 	 dbn LogisticRegression 900 0.0762 +/- 0.0076
# 	 dbn REPD 900 0.1974 +/- 0.004
#
# 	 da DecisionTreeClassifier 900 0.1936 +/- 0.0093
# 	 da GaussianNB 900 0.3484 +/- 0.0085
# 	 da KNeighborsClassifier 900 0.2571 +/- 0.0108
# 	 da LogisticRegression 900 0.0433 +/- 0.0066
# 	 da REPD 900 0.2671 +/- 0.0072
# KNeighborsClassifier REPD
# Overlap count: 1
#
# 	 ca DecisionTreeClassifier 900 0.1897 +/- 0.0094
# 	 ca GaussianNB 900 0.3978 +/- 0.01
# 	 ca KNeighborsClassifier 900 0.1722 +/- 0.01
# 	 ca LogisticRegression 900 0.0 +/- 0.0
# 	 ca REPD 900 0.3462 +/- 0.009
#
#
#
# ant 1.6
# 	 dbn DecisionTreeClassifier 900 0.2807 +/- 0.0062
# 	 dbn GaussianNB 900 0.2512 +/- 0.0066
# 	 dbn KNeighborsClassifier 900 0.1659 +/- 0.0065
# 	 dbn LogisticRegression 900 0.2276 +/- 0.0061
# 	 dbn REPD 900 0.4162 +/- 0.0039
#
# 	 da DecisionTreeClassifier 900 0.4969 +/- 0.0065
# 	 da GaussianNB 900 0.6396 +/- 0.0055
# 	 da KNeighborsClassifier 900 0.5619 +/- 0.006
# 	 da LogisticRegression 900 0.6228 +/- 0.0054
# 	 da REPD 900 0.5026 +/- 0.0074
# DecisionTreeClassifier REPD
# Overlap count: 1
#
# 	 ca DecisionTreeClassifier 900 0.5087 +/- 0.0064
# 	 ca GaussianNB 900 0.5824 +/- 0.0101
# 	 ca KNeighborsClassifier 900 0.557 +/- 0.0063
# 	 ca LogisticRegression 900 0.0355 +/- 0.0057
# 	 ca REPD 900 0.598 +/- 0.0073
# GaussianNB REPD
# Overlap count: 1
#
#
#
# camel 1.2
# 	 dbn DecisionTreeClassifier 900 0.3723 +/- 0.0043
# 	 dbn GaussianNB 900 0.2875 +/- 0.0041
# 	 dbn KNeighborsClassifier 900 0.3212 +/- 0.0044
# 	 dbn LogisticRegression 900 0.3165 +/- 0.0042
# 	 dbn REPD 900 0.5225 +/- 0.0028
#
# 	 da DecisionTreeClassifier 900 0.403 +/- 0.0043
# 	 da GaussianNB 900 0.2615 +/- 0.0058
# 	 da KNeighborsClassifier 900 0.3653 +/- 0.0043
# 	 da LogisticRegression 900 0.2057 +/- 0.005
# 	 da REPD 900 0.4081 +/- 0.0059
# DecisionTreeClassifier REPD
# Overlap count: 1
#
# 	 ca DecisionTreeClassifier 900 0.4066 +/- 0.0042
# 	 ca GaussianNB 900 0.2497 +/- 0.0056
# 	 ca KNeighborsClassifier 900 0.3538 +/- 0.0045
# 	 ca LogisticRegression 900 0.0095 +/- 0.002
# 	 ca REPD 900 0.3671 +/- 0.0059
#
#
#
# camel 1.4
# 	 dbn DecisionTreeClassifier 900 0.1945 +/- 0.0045
# 	 dbn GaussianNB 900 0.095 +/- 0.0045
# 	 dbn KNeighborsClassifier 900 0.0998 +/- 0.0044
# 	 dbn LogisticRegression 900 0.1005 +/- 0.0046
# 	 dbn REPD 900 0.2863 +/- 0.0028
#
# 	 da DecisionTreeClassifier 900 0.2472 +/- 0.0048
# 	 da GaussianNB 900 0.3386 +/- 0.0042
# 	 da KNeighborsClassifier 900 0.2223 +/- 0.0049
# 	 da LogisticRegression 900 0.043 +/- 0.0034
# 	 da REPD 900 0.3155 +/- 0.0044
#
# 	 ca DecisionTreeClassifier 900 0.2436 +/- 0.0047
# 	 ca GaussianNB 900 0.3029 +/- 0.0065
# 	 ca KNeighborsClassifier 900 0.1563 +/- 0.0047
# 	 ca LogisticRegression 900 0.0003 +/- 0.0003
# 	 ca REPD 900 0.309 +/- 0.0045
# GaussianNB REPD
# Overlap count: 1
#
#
#
# log4j 1.1
# 	 dbn DecisionTreeClassifier 900 0.3734 +/- 0.0105
# 	 dbn GaussianNB 900 0.2833 +/- 0.0106
# 	 dbn KNeighborsClassifier 900 0.2965 +/- 0.0101
# 	 dbn LogisticRegression 900 0.3151 +/- 0.0097
# 	 dbn REPD 900 0.5126 +/- 0.0071
#
# 	 da DecisionTreeClassifier 900 0.5694 +/- 0.0104
# 	 da GaussianNB 900 0.6475 +/- 0.0096
# 	 da KNeighborsClassifier 900 0.5833 +/- 0.0092
# 	 da LogisticRegression 900 0.6244 +/- 0.0094
# 	 da REPD 900 0.4997 +/- 0.0104
#
# 	 ca DecisionTreeClassifier 900 0.5602 +/- 0.0103
# 	 ca GaussianNB 900 0.6204 +/- 0.0107
# 	 ca KNeighborsClassifier 900 0.5923 +/- 0.0094
# 	 ca LogisticRegression 900 0.0 +/- 0.0
# 	 ca REPD 900 0.6163 +/- 0.01
# GaussianNB REPD
# Overlap count: 1
#
#
#
# log4j 1.2
# 	 dbn DecisionTreeClassifier 900 0.9455 +/- 0.0016
# 	 dbn GaussianNB 900 0.9608 +/- 0.0017
# 	 dbn KNeighborsClassifier 900 0.976 +/- 0.0011
# 	 dbn LogisticRegression 900 0.9776 +/- 0.001
# 	 dbn REPD 900 0.9776 +/- 0.001
# KNeighborsClassifier REPD
# LogisticRegression REPD
# Overlap count: 2
#
# 	 da DecisionTreeClassifier 900 0.9548 +/- 0.0015
# 	 da GaussianNB 900 0.6868 +/- 0.0076
# 	 da KNeighborsClassifier 900 0.9738 +/- 0.0011
# 	 da LogisticRegression 900 0.979 +/- 0.001
# 	 da REPD 900 0.8152 +/- 0.0055
#
# 	 ca DecisionTreeClassifier 900 0.9547 +/- 0.0016
# 	 ca GaussianNB 900 0.7643 +/- 0.0054
# 	 ca KNeighborsClassifier 900 0.9757 +/- 0.001
# 	 ca LogisticRegression 900 0.9793 +/- 0.001
# 	 ca REPD 900 0.8011 +/- 0.0072
#
#
#
# poi 2.0
# 	 dbn DecisionTreeClassifier 900 0.145 +/- 0.0073
# 	 dbn GaussianNB 900 0.1291 +/- 0.0077
# 	 dbn KNeighborsClassifier 900 0.0434 +/- 0.006
# 	 dbn LogisticRegression 900 0.0865 +/- 0.0073
# 	 dbn REPD 900 0.2124 +/- 0.0042
#
# 	 da DecisionTreeClassifier 900 0.1642 +/- 0.0086
# 	 da GaussianNB 900 0.2199 +/- 0.0086
# 	 da KNeighborsClassifier 900 0.0826 +/- 0.0077
# 	 da LogisticRegression 900 0.1036 +/- 0.009
# 	 da REPD 900 0.2169 +/- 0.0057
# GaussianNB REPD
# Overlap count: 1
#
# 	 ca DecisionTreeClassifier 900 0.1853 +/- 0.0082
# 	 ca GaussianNB 900 0.238 +/- 0.0078
# 	 ca KNeighborsClassifier 900 0.0883 +/- 0.0074
# 	 ca LogisticRegression 900 0.0 +/- 0.0
# 	 ca REPD 900 0.2359 +/- 0.0072
# GaussianNB REPD
# Overlap count: 1
#
#
#
# poi 2.5
# 	 dbn DecisionTreeClassifier 900 0.6397 +/- 0.0036
# 	 dbn GaussianNB 900 0.6675 +/- 0.0035
# 	 dbn KNeighborsClassifier 900 0.6735 +/- 0.0032
# 	 dbn LogisticRegression 900 0.6686 +/- 0.0033
# 	 dbn REPD 900 0.7851 +/- 0.0023
#
# 	 da DecisionTreeClassifier 900 0.7367 +/- 0.0033
# 	 da GaussianNB 900 0.5767 +/- 0.0086
# 	 da KNeighborsClassifier 900 0.7739 +/- 0.0027
# 	 da LogisticRegression 900 0.8178 +/- 0.0023
# 	 da REPD 900 0.6869 +/- 0.0072
#
# 	 ca DecisionTreeClassifier 900 0.7445 +/- 0.0031
# 	 ca GaussianNB 900 0.5351 +/- 0.0091
# 	 ca KNeighborsClassifier 900 0.7851 +/- 0.0028
# 	 ca LogisticRegression 900 0.7922 +/- 0.0024
# 	 ca REPD 900 0.5733 +/- 0.0098
