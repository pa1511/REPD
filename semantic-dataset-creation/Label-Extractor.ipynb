# %%
import pandas as pd
import numpy as np

# %%
dataset_name = "ant-1.7"

# %%
dataset = pd.read_csv("original-data/"+dataset_name+".csv")

# %%
dataset.describe()
# Out:
#             version         wmc         dit         noc         cbo  \
# count  7.450000e+02  745.000000  745.000000  745.000000  745.000000
# mean   1.700000e+00   11.071141    2.522148    0.731544   11.046980
# std    2.221938e-16   11.975963    1.398869    4.800357   26.343149
# min    1.700000e+00    0.000000    1.000000    0.000000    0.000000
# 25%    1.700000e+00    4.000000    1.000000    0.000000    4.000000
# 50%    1.700000e+00    7.000000    2.000000    0.000000    6.000000
# 75%    1.700000e+00   14.000000    4.000000    0.000000   11.000000
# max    1.700000e+00  120.000000    7.000000  102.000000  499.000000
#
#               rfc         lcom          ca          ce         npm  ...  \
# count  745.000000   745.000000  745.000000  745.000000  745.000000  ...
# mean    34.362416    89.147651    5.655034    5.746309    8.365101  ...
# std     36.024972   349.937555   25.814223    5.653176    9.331319  ...
# ...

# %%
dataset.head()
# Out:
#   name  version                                             name.1  wmc  dit  \
# 0  ant      1.7  org.apache.tools.ant.taskdefs.rmic.RmicAdapter...    3    1
# 1  ant      1.7  org.apache.tools.ant.taskdefs.optional.perforc...    5    2
# 2  ant      1.7  org.apache.tools.ant.taskdefs.optional.junit.O...    1    2
# 3  ant      1.7  org.apache.tools.ant.taskdefs.optional.perforc...    8    1
# 4  ant      1.7              org.apache.tools.ant.taskdefs.WaitFor    9    3
#
#    noc  cbo  rfc  lcom  ca  ...  dam  moa  mfa       cam  ic  cbm        amc  \
# 0    0   10   18     3   1  ...  0.0    0  0.0  0.444444   0    0  32.666667
# 1    0    4   13     0   1  ...  1.0    1  0.7  0.500000   0    0  13.400000
# 2    0    1    3     0   0  ...  0.0    0  1.0  1.000000   0    0   6.000000
# 3    9   13   20    12   9  ...  0.2    1  0.0  0.406250   0    0  11.000000
# 4    0    5   26    16   0  ...  1.0    0  0.8  0.388889   0    0  19.000000
#
#    max_cc  avg_cc  bug
# ...

# %%
for i in range(len(dataset)):
    print(dataset["name.1"][i]+"="+str(dataset["bug"][i]))
# Out:
# org.apache.tools.ant.taskdefs.rmic.RmicAdapterFactory=0
# org.apache.tools.ant.taskdefs.optional.perforce.FStatP4OutputHandler=0
# org.apache.tools.ant.taskdefs.optional.junit.OutErrSummaryJUnitResultFormatter=0
# org.apache.tools.ant.taskdefs.optional.perforce.P4HandlerAdapter=0
# org.apache.tools.ant.taskdefs.WaitFor=1
# org.apache.tools.ant.taskdefs.optional.depend.constantpool.ConstantCPInfo=0
# org.apache.tools.zip.AsiExtraField=1
# org.apache.tools.ant.types.resources.selectors.Date=0
# org.apache.tools.ant.util.facade.FacadeTaskHelper=0
# org.apache.tools.ant.types.selectors.DepthSelector=0
# org.apache.tools.ant.taskdefs.optional.dotnet.JSharp=0
# org.apache.tools.ant.taskdefs.LogStreamHandler=0
# org.apache.tools.ant.input.InputHandler=0
# org.apache.tools.zip.JarMarker=0
# org.apache.tools.ant.taskdefs.optional.clearcase.CCMkbl=0
# org.apache.tools.ant.types.resources.Restrict=0
# org.apache.tools.ant.DemuxInputStream=0
# ...

# %%
file = open("config/labels-"+str(dataset_name)+".properties","w") 
for i in range(len(dataset)):
    file.write(dataset["name.1"][i]+"="+str(dataset["bug"][i]))
    file.write("\n")
file.flush()
file.close()
